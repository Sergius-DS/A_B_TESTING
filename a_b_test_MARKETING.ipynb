# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergius-DS/A_B_TESTING/blob/main/a_b_test_MARKETING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

from scipy.stats import chi2_contingency
from scipy.stats import shapiro, levene, ttest_ind, mannwhitneyu

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
df = pd.read_csv('marketing_AB.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0           0  1069124         ad      False        130       Monday
# 1           1  1119715         ad      False         93      Tuesday
# 2           2  1144181         ad      False         21      Tuesday
# 3           3  1435133         ad      False        355      Tuesday
# 4           4  1015700         ad      False        276       Friday
#
#    most ads hour
# 0             20
# 1             22
# 2             18
# 3             10
# 4             14

# %%
df.duplicated(subset = 'user id').sum()
# Out:
# 0

# %%
df.drop(['Unnamed: 0', 'user id'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#   test group  converted  total ads most ads day  most ads hour
# 0         ad      False        130       Monday             20
# 1         ad      False         93      Tuesday             22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588101 entries, 0 to 588100
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   test group     588101 non-null  object
#  1   converted      588101 non-null  bool
#  2   total ads      588101 non-null  int64
#  3   most ads day   588101 non-null  object
#  4   most ads hour  588101 non-null  int64
# dtypes: bool(1), int64(2), object(2)
# memory usage: 18.5+ MB

# %%
df_cat = df[['test group', 'converted', 'most ads day', 'most ads hour']]
df_cat.nunique()
# Out:
# test group        2
# converted         2
# most ads day      7
# most ads hour    24
# dtype: int64

# %%
df.groupby('test group')['test group'].value_counts()
# Out:
# test group
# ad     564577
# psa     23524
# Name: count, dtype: int64

# %%
# CHECKING DISTRIBUTION OF CONVERTED WITHIN TEST GROUPS
result = pd.crosstab(df['test group'], df['converted'])
print(result)
# Out:
# converted    False  True
# test group
# ad          550154  14423
# psa          23104    420

# %%
df.groupby('test group')['total ads'].count()
# Out:
# test group
# ad     564577
# psa     23524
# Name: total ads, dtype: int64

# %% [markdown]
# UNIQUE VALUES IN EACH CATEGORICAL COLUMN

# %%
for i in df_cat.columns:
  print(i.upper(), ":", df_cat[i].unique())
# Out:
# TEST GROUP : ['ad' 'psa']
# CONVERTED : [False  True]
# MOST ADS DAY : ['Monday' 'Tuesday' 'Friday' 'Saturday' 'Wednesday' 'Sunday' 'Thursday']
# MOST ADS HOUR : [20 22 18 10 14 13 19 11 12 16 21  3 23  4  8  0  2 15  1  6 17  7  9  5]

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# TEST GROUP

# %%
variable = 'test group'

plt.figure(figsize = (6,4))
plt.subplot(1,2,1)
sns.countplot(x=variable, data=df_cat)
plt.title(f'Count Plot - {variable}')

plt.subplot(1,2,2)
counts = df_cat[variable].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# CONVERTED

# %%
variable = 'converted'

plt.figure(figsize = (6,4))
plt.subplot(1,2,1)
sns.countplot(x=variable, data=df_cat)
plt.title(f'Count Plot - {variable}')

plt.subplot(1,2,2)
counts = df_cat[variable].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# MOST ADS PER DAY

# %%
variable = 'most ads day'

plt.figure(figsize = (6,4))
plt.subplot(1,2,1)
sns.countplot(x=variable, data=df_cat, order = df_cat[variable].value_counts().index)
plt.xticks(rotation = 90)
plt.title(f'Count Plot - {variable}')

plt.subplot(1,2,2)
counts = df_cat[variable].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.2f%%')
plt.title(f'Pie Chart - {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# MOST ADS PER HOUR

# %%
# Calcular los conteos
conteos = df_cat['most ads hour'].value_counts()

# Ordenar los conteos en orden descendente
conteos = conteos.sort_values(ascending=False)

# Calcular los porcentajes
porcentaje = conteos / conteos.sum() * 100

# Crear la gráfica
ax = conteos.plot.bar(color='lightblue', figsize=(10, 6), width=0.8)

# Calculate max_height here based on your data
max_height = conteos.min()

for i, (index, value) in enumerate(conteos.items()):
    percent = porcentaje[index]

    # Adjust y-position based on maximum height
    y_pos = max_height * (4.8 if percent >= 2.99 else 0)  # 4.8 for inside, 0 for outside

    if percent >= 2.99:
        ax.text(i, y_pos, f'{percent:.2f}%', ha='center', va='center', rotation=90, color='black')
    else:
        ax.text(i, value, f'{percent:.2f}%', ha='center', va='bottom', rotation=90)

# Configurar etiquetas y título
ax.set_ylabel('Conteo')
ax.set_title('Most Ads Hour')
ax.set_xlabel('Hour')

# Use FixedLocator to specify the desired ticks
ax.xaxis.set_major_locator(ticker.FixedLocator(range(0,24)))

# %% [markdown]
# TOTAL ADS

# %%
variable = 'total ads'

plt.figure(figsize = (6,4))
plt.subplot(1,2,1)
sns.histplot(x=variable, data=df)
plt.xticks(rotation = 90)
plt.title(f'Histogram - {variable}')

plt.subplot(1,2,2)
sns.boxplot(y = variable, data = df)
plt.title(f'Pie Chart - {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **OBSERVATIONS:**
#
# Because there is outliers, it is not possible to see small values

# %%
df['total ads'].describe()
# Out:
# count    588101.000000
# mean         24.820876
# std          43.715181
# min           1.000000
# 25%           4.000000
# 50%          13.000000
# 75%          27.000000
# max        2065.000000
# Name: total ads, dtype: float64

# %%
variable = 'total ads'

plt.figure(figsize = (6,4))
plt.subplot(1,2,1)
sns.histplot(x=variable, data=df[df['total ads'] < 48])
plt.xticks(rotation = 90)
plt.title(f'Histogram - {variable}')

plt.subplot(1,2,2)
sns.boxplot(y = variable, data = df[df['total ads']< 48])
plt.title(f'Pie Chart - {variable}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **OBSERVATIONS:**
#
# Median and Mean is around 10 ads

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
df.columns
# Out:
# Index(['test group', 'converted', 'total ads', 'most ads day',
#        'most ads hour'],
#       dtype='object')

# %%
ct_conversion_test_group = pd.crosstab(df['test group'], df['converted'], normalize = 'index')
ct_conversion_test_group
# Out:
# converted      False     True
# test group
# ad          0.974453  0.025547
# psa         0.982146  0.017854

# %%
ct_conversion_test_group.plot.bar(stacked = True)
plt.xlabel('Test Group') # Changed from plt.set_xlabel to plt.xlabel
plt.ylabel('Conversion Rate') # Changed from plt.set_ylabel to plt.ylabel
plt.title('Conversion Rate by Test Group')
plt.show()

# %%
ct_conversion_day = pd.crosstab(df['most ads day'], df['converted'], normalize = 'index')
print(ct_conversion_day.sort_values(by = True, ascending = False))
ct_conversion_day.plot.bar(stacked = True)
plt.xlabel('Day')
plt.ylabel('Conversion Rate')
plt.title('Conversion Rate by Day')
plt.show()
# Out:
# converted        False     True
# most ads day
# Monday        0.967188  0.032812
# Tuesday       0.970160  0.029840
# Wednesday     0.975058  0.024942
# Sunday        0.975524  0.024476
# Friday        0.977788  0.022212
# Thursday      0.978429  0.021571
# Saturday      0.978949  0.021051

# %%
ct_conversion_hour = pd.crosstab(df['most ads hour'], df['converted'], normalize = 'index')
print(ct_conversion_hour.sort_values(by = True, ascending=False))
ct_conversion_hour.plot.bar(stacked = True)
plt.xlabel('Hour')
plt.ylabel('Conversion Rate')
plt.title('Conversion Rate by Hour')
plt.show()
# Out:
# converted         False     True
# most ads hour
# 16             0.969228  0.030772
# 20             0.970197  0.029803
# 15             0.970347  0.029653
# 21             0.971077  0.028923
# 17             0.971790  0.028210
# 14             0.971937  0.028063
# 18             0.972620  0.027380
# 19             0.973280  0.026720
# 22             0.973895  0.026105
# 13             0.975323  0.024677
# 12             0.976172  0.023828
# 23             0.977338  0.022662
# 6              0.977756  0.022244
# 11             0.977884  0.022116
# 10             0.978479  0.021521
# 5              0.979085  0.020915
# 8              0.980484  0.019516
# 9              0.980809  0.019191
# 0              0.981575  0.018425
# 7              0.981889  0.018111
# 4              0.984765  0.015235
# 1              0.987089  0.012911
# 3              0.989548  0.010452
# 2              0.992687  0.007313

# %%
sns.boxplot(x = 'converted', y = 'total ads', data = df[df['total ads']< 50], hue = 'converted')
plt.title('Conversion Rate vs Total Ads')
plt.show()

# %% [markdown]
# ## STATISTICAL TESTS

# %%
alpha = 0.05
for variable in df_cat.columns:
  if variable != 'converted':
    # Crear table contingencia
    contingency_table = pd.crosstab(df_cat[variable], df_cat['converted'])

    chi2, p, _, _ = chi2_contingency(contingency_table)

    print(f"\nChi-squared test for {variable} vs converted:")
    print(f"Chi-squared value: {chi2}")
    print(f"p-value: {p}")

    if p < alpha:
      print(f"The difference in conversion rates across {variable} is statistically significant")
    else:
      print(f"There is no significant difference in conversion rates across {variable}")
# Out:
# Chi-squared test for test group vs converted:
# Chi-squared value: 54.005823883685245
# p-value: 1.9989623063390075e-13
# The difference in conversion rates across test group is statistically significant
#
# Chi-squared test for most ads day vs converted:
# Chi-squared value: 410.0478857936585
# p-value: 1.932184379244731e-85
# The difference in conversion rates across most ads day is statistically significant
#
# Chi-squared test for most ads hour vs converted:
# Chi-squared value: 430.76869230822086
# p-value: 8.027629823696771e-77
# The difference in conversion rates across most ads hour is statistically significant

# %%
# Normality assumption
shapiro_stat_true, shapiro_p_value_true = shapiro(df[df['converted'] == True]['total ads'])
shapiro_stat_false, shapiro_p_value_false = shapiro(df[df['converted'] == False]['total ads'])
print(f"Shapiro-Wilk test for normality (True group): p-value = {shapiro_p_value_true}")
print(f"Shapiro-Wilk test for normality (False group): p-value = {shapiro_p_value_false}")
# Equeality of variances
levene_stat, levene_p_value = levene(df[df['converted'] == True]['total ads'], df[df['converted'] == False]['total ads'])
print(f"Levene test for equality of variances: p-value = {levene_p_value}")
# Out:
# Shapiro-Wilk test for normality (True group): p-value = 1.638680987007771e-98
# Shapiro-Wilk test for normality (False group): p-value = 9.883049430735801e-204
# Levene test for equality of variances: p-value = 0.0

# %% [markdown]
# **OBSERVATIONS:**
#
# The distribution of "total ads" is not normal for both converted and non-converted groups (p-values much smaller than the significance level alpha = 0.05).
#
# This violates a key assumption for the t-test
#
# The Levene test showed a significant difference in variances (p-value = 0) between the "total ads" for converted and non-converted groups. This further weakens the applicability of the t-test.

# %%
alpha = 0.05
if shapiro_p_value_true > alpha and shapiro_p_value_false > alpha and levene_p_value > alpha:
  # Assumptions met - use t-test for means
  t_stat, t_p_value = ttest_ind(df[df['converted']]['total ads'], df[~df['converted']]['total ads'])
  print(f"Independent two sample t-test: p-value = {t_p_value}")
else:
  # Assumptions not met -use Mann-Whitney U test for medians
  u_stat, u_p_value = mannwhitneyu(df[df['converted']]['total ads'], df[~df['converted']]['total ads'])
  print(f"Mann-Whitney U test: p-value = {u_p_value}")
# Out:
# Mann-Whitney U test: p-value = 0.0

# %% [markdown]
# **OBSERVATIONS:**
#
# p-value of 0.0 is an extremely small value, suggesting very strong evidence against the null hypothesis.
#
# Mann-Whitney U test provides strong evidence to conclude that there is a significant difference in the medians of the total ads between the converted and non-converted groups.
